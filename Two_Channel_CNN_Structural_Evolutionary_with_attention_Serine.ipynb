# %% [markdown]
# <a href="https://colab.research.google.com/github/faisalahm3d/Research/blob/master/Two_Channel_CNN_Structural_Evolutionary_with_attention_Serine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np

# %%
def calculate_performance(test_num, pred_y, labels):
    tp = 0
    fp = 0
    tn = 0
    fn = 0
    for index in range(test_num):
        if labels[index] == 1:
            if labels[index] == pred_y[index]:
                tp = tp + 1
            else:
                fn = fn + 1
        else:
            if labels[index] == pred_y[index]:
                tn = tn + 1
            else:
                fp = fp + 1

    # entering any of the else statement means that the evaluation metric is invalid
    acc = float(tp + tn) / test_num
    
    if((tp + fp) != 0):
      sensitivity = float(tp) / (tp + fn)
    else:
      sensitivity = 0

    if((tn + fp) != 0):
      specificity = float(tn) / (tn + fp)
    else:
      specificity = 0
    
    precision = tp / (tp + fp)

    MCC = float(tp * tn - fp * fn) / (np.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn)))
    
    return acc, sensitivity, specificity, precision, MCC

# %%
import numpy as np
npzfile = np.load('/content/drive/MyDrive/DLPhos/normalized_balanced_pssm_spd_profile/train_balanced_S_10.npz', allow_pickle=True)
x_train= npzfile['arr_0']
y_train= npzfile['arr_1']
x_test = npzfile['arr_2']
y_test = npzfile['arr_3']

# %%
from sklearn.model_selection import train_test_split
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.10, random_state=10)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.fit_transform(x_test)

# %%
y_test
# Out:
# array([0, 0, 0, ..., 1, 1, 0], dtype=int32)

# %%
from tensorflow.keras.utils import to_categorical as labelEncoding
y_train = labelEncoding(y_train, dtype=int)
y_test  = labelEncoding(y_test, dtype=int)

# %%
def get_pssm_spd(data):
  row, col = data.shape
  print (row)
  pssm= data[:, :420]
  spd = data[:, 420:]
  return np.array([pssm[r,:].reshape(21,20) for r in range(row)]), np.array([spd[r, :].reshape(21,8) for r in range(row)])

# %%
x_test.shape
# Out:
# (7306, 588)

# %%
x_train.shape
# Out:
# (55182, 588)

# %%
trainX1, trainX2 = get_pssm_spd(x_train)
testX1, testX2 = get_pssm_spd(x_test)
valX1, valtX2 = get_pssm_spd(x_val)
# Out:
# 49663
# 7306
# 5519

# %%
trainX1.shape
# Out:
# (46904, 21, 20)

# %%
from keras.layers import Input, Conv1D, Dense, Activation, Dropout, MaxPooling1D, Flatten,concatenate,GlobalMaxPool1D
from keras import Model
from tensorflow.keras.optimizers import (RMSprop, Adam, SGD)
from keras.models import load_model
from tensorflow.keras.utils import plot_model
from keras import regularizers
from keras.regularizers import (l1, l2, l1_l2)
from keras.callbacks import (EarlyStopping, ModelCheckpoint)
from tensorflow.keras.optimizers import (RMSprop, Adam, SGD)
from keras.layers import (Input, Dense, Dropout, Flatten, BatchNormalization,
                                     Conv1D, Conv2D, MaxPooling1D, MaxPooling2D,
                                     LSTM, GRU, Embedding, Bidirectional, Concatenate)

# %%
def get_structural_model():
    ### Head-1:
    input1 = Input(shape=trainX2[0].shape)

    x = Conv1D(filters=32, kernel_size=3, padding='same', kernel_regularizer=l2(l=0.01))(input1)
    #x = BatchNormalization()(x)
    x = Dropout(rate=0.5)(x)

    #x = Conv1D(filters=8, kernel_size=3, padding='same', activation='relu', kernel_regularizer=l2(l=0.01))(x)
    #x = BatchNormalization()(x)
    #x = Dropout(rate=0.50)(x)

    head1 = Flatten()(x)

    z= Dense(units=256, activation='relu',)(head1)
    z = Dropout(rate=0.5)(z)

    z = Dense(units=64, activation='relu',)(z)
    z = Dropout(rate=0.5)(z)

    z = Dense(units=16, activation='relu',)(z)
    z = Dropout(rate=0.5)(z)
    
    z = Dense(1, activation='sigmoid')(z)

    return Model(inputs=[input1], outputs=[z])
#end-def

# %%
model = get_structural_model()
model.summary()
plot_model(model, to_file='model-spd.png', show_shapes=True, show_layer_names=False, expand_nested=True)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 21, 8)]           0
#
#  conv1d (Conv1D)             (None, 21, 32)            800
#
#  dropout (Dropout)           (None, 21, 32)            0
#
#  flatten (Flatten)           (None, 672)               0
#
#  dense (Dense)               (None, 256)               172288
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 64)                16448
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 16)                1040
#
#  dropout_3 (Dropout)         (None, 16)                0
#
#  dense_3 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 190,593
# Trainable params: 190,593
# Non-trainable params: 0
# _________________________________________________________________

# %%
# patient early stopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=20)
# save the best model
mc = ModelCheckpoint('best_model_spd.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)

# %%
# Compile Model:
#model = Ne()
model.compile(optimizer=Adam(learning_rate=0.0005),
              loss='binary_crossentropy',
              metrics=['accuracy'])

# Run Model:
history = model.fit(x=trainX2, y= y_train, validation_data=(testX2, y_test), batch_size=32, epochs=200, verbose=1, callbacks=[es,mc])
# Out:
# Epoch 1/200
# 1663/1669 [============================>.] - ETA: 0s - loss: 0.7428 - accuracy: 0.5876
# Epoch 1: val_accuracy improved from -inf to 0.68307, saving model to best_model_spd.h5
# 1669/1669 [==============================] - 10s 6ms/step - loss: 0.7425 - accuracy: 0.5876 - val_loss: 0.6583 - val_accuracy: 0.6831
# Epoch 2/200
# 1664/1669 [============================>.] - ETA: 0s - loss: 0.6451 - accuracy: 0.6449
# Epoch 2: val_accuracy improved from 0.68307 to 0.69825, saving model to best_model_spd.h5
# 1669/1669 [==============================] - 9s 5ms/step - loss: 0.6451 - accuracy: 0.6450 - val_loss: 0.6039 - val_accuracy: 0.6982
# Epoch 3/200
# 1667/1669 [============================>.] - ETA: 0s - loss: 0.6054 - accuracy: 0.6855
# Epoch 3: val_accuracy improved from 0.69825 to 0.72606, saving model to best_model_spd.h5
# 1669/1669 [==============================] - 9s 5ms/step - loss: 0.6053 - accuracy: 0.6856 - val_loss: 0.5570 - val_accuracy: 0.7261
# Epoch 4/200
# 1668/1669 [============================>.] - ETA: 0s - loss: 0.5595 - accuracy: 0.7289
# Epoch 4: val_accuracy improved from 0.72606 to 0.73972, saving model to best_model_spd.h5
# 1669/1669 [==============================] - 9s 6ms/step - loss: 0.5595 - accuracy: 0.7289 - val_loss: 0.5429 - val_accuracy: 0.7397
# Epoch 5/200
# 1669/1669 [==============================] - ETA: 0s - loss: 0.5244 - accuracy: 0.7575
# Epoch 5: val_accuracy improved from 0.73972 to 0.74140, saving model to best_model_spd.h5
# 1669/1669 [==============================] - 9s 5ms/step - loss: 0.5244 - accuracy: 0.7575 - val_loss: 0.5232 - val_accuracy: 0.7414
# Epoch 6/200
# 1668/1669 [============================>.] - ETA: 0s - loss: 0.5003 - accuracy: 0.7737
# Epoch 6: val_accuracy improved from 0.74140 to 0.78152, saving model to best_model_spd.h5
# 1669/1669 [==============================] - 9s 5ms/step - loss: 0.5003 - accuracy: 0.7736 - val_loss: 0.4874 - val_accuracy: 0.7815
# Epoch 7/200
# 1665/1669 [============================>.] - ETA: 0s - loss: 0.4801 - accuracy: 0.7889
# Epoch 7: val_accuracy improved from 0.78152 to 0.79467, saving model to best_model_spd.h5
# 1669/1669 [==============================] - 10s 6ms/step - loss: 0.4803 - accuracy: 0.7888 - val_loss: 0.4639 - val_accuracy: 0.7947
# Epoch 8/200
# 1663/1669 [============================>.] - ETA: 0s - loss: 0.4614 - accuracy: 0.8003
# Epoch 8: val_accuracy improved from 0.79467 to 0.82232, saving model to best_model_spd.h5
# 1669/1669 [==============================] - 9s 5ms/step - loss: 0.4613 - accuracy: 0.8002 - val_loss: 0.4300 - val_accuracy: 0.8223
# Epoch 9/200
# 1665/1669 [============================>.] - ETA: 0s - loss: 0.4449 - accuracy: 0.8103
# Epoch 9: val_accuracy did not improve from 0.82232
# 1669/1669 [==============================] - 9s 5ms/step - loss: 0.4451 - accuracy: 0.8103 - val_loss: 0.4634 - val_accuracy: 0.8023
# Epoch 10/200
# 1667/1669 [============================>.] - ETA: 0s - loss: 0.4364 - accuracy: 0.8185
# Epoch 10: val_accuracy did not improve from 0.82232
# 1669/1669 [==============================] - 11s 7ms/step - loss: 0.4365 - accuracy: 0.8185 - val_loss: 0.4348 - val_accuracy: 0.8179
# Epoch 11/200
# 1660/1669 [============================>.] - ETA: 0s - loss: 0.4221 - accuracy: 0.8279
# Epoch 11: val_accuracy did not improve from 0.82232
# 1669/1669 [==============================] - 9s 6ms/step - loss: 0.4220 - accuracy: 0.8280 - val_loss: 0.4379 - val_accuracy: 0.8093
# Epoch 12/200
# 1662/1669 [============================>.] - ETA: 0s - loss: 0.4168 - accuracy: 0.8284
# Epoch 12: val_accuracy did not improve from 0.82232
# 1669/1669 [==============================] - 9s 6ms/step - loss: 0.4168 - accuracy: 0.8283 - val_loss: 0.4406 - val_accuracy: 0.8114
# Epoch 13/200
# 1669/1669 [==============================] - ETA: 0s - loss: 0.4079 - accuracy: 0.8332
# Epoch 13: val_accuracy improved from 0.82232 to 0.84356, saving model to best_model_spd.h5
# 1669/1669 [==============================] - 9s 6ms/step - loss: 0.4079 - accuracy: 0.8332 - val_loss: 0.3900 - val_accuracy: 0.8436
# Epoch 14/200
# 1666/1669 [============================>.] - ETA: 0s - loss: 0.3988 - accuracy: 0.8380
# Epoch 14: val_accuracy did not improve from 0.84356
# 1669/1669 [==============================] - 9s 5ms/step - loss: 0.3989 - accuracy: 0.8380 - val_loss: 0.4066 - val_accuracy: 0.8350
# Epoch 15/200
# 1661/1669 [============================>.] - ETA: 0s - loss: 0.3937 - accuracy: 0.8445
# Epoch 15: val_accuracy improved from 0.84356 to 0.85941, saving model to best_model_spd.h5
# 1669/1669 [==============================] - 9s 5ms/step - loss: 0.3934 - accuracy: 0.8446 - val_loss: 0.3532 - val_accuracy: 0.8594
# Epoch 16/200
# 1665/1669 [============================>.] - ETA: 0s - loss: 0.3862 - accuracy: 0.8478
# Epoch 16: val_accuracy improved from 0.85941 to 0.86902, saving model to best_model_spd.h5
# 1669/1669 [==============================] - 9s 5ms/step - loss: 0.3861 - accuracy: 0.8478 - val_loss: 0.3339 - val_accuracy: 0.8690
# Epoch 17/200
# 1669/1669 [==============================] - ETA: 0s - loss: 0.3786 - accuracy: 0.8486
# Epoch 17: val_accuracy did not improve from 0.86902
# 1669/1669 [==============================] - 9s 5ms/step - loss: 0.3786 - accuracy: 0.8486 - val_loss: 0.3557 - val_accuracy: 0.8597
# Epoch 18/200
# 1666/1669 [============================>.] - ETA: 0s - loss: 0.3747 - accuracy: 0.8535
# Epoch 18: val_accuracy did not improve from 0.86902
# 1669/1669 [==============================] - 9s 6ms/step - loss: 0.3747 - accuracy: 0.8534 - val_loss: 0.3546 - val_accuracy: 0.8602
# Epoch 19/200
# 1667/1669 [============================>.] - ETA: 0s - loss: 0.3748 - accuracy: 0.8557
# Epoch 19: val_accuracy did not improve from 0.86902
# 1669/1669 [==============================] - 9s 5ms/step - loss: 0.3747 - accuracy: 0.8557 - val_loss: 0.3508 - val_accuracy: 0.8638
# Epoch 20/200
# 1663/1669 [============================>.] - ETA: 0s - loss: 0.3664 - accuracy: 0.8572
# Epoch 20: val_accuracy improved from 0.86902 to 0.89666, saving model to best_model_spd.h5
# 1669/1669 [==============================] - 9s 5ms/step - loss: 0.3664 - accuracy: 0.8572 - val_loss: 0.2889 - val_accuracy: 0.8967
# Epoch 21/200
# 1663/1669 [============================>.] - ETA: 0s - loss: 0.3627 - accuracy: 0.8589
# Epoch 21: val_accuracy did not improve from 0.89666
# 1669/1669 [==============================] - 9s 5ms/step - loss: 0.3628 - accuracy: 0.8588 - val_loss: 0.3293 - val_accuracy: 0.8692
# Epoch 22/200
# 1669/1669 [==============================] - ETA: 0s - loss: 0.3613 - accuracy: 0.8611
# Epoch 22: val_accuracy did not improve from 0.89666
# 1669/1669 [==============================] - 9s 5ms/step - loss: 0.3613 - accuracy: 0.8611 - val_loss: 0.3106 - val_accuracy: 0.8865
# Epoch 23/200
# 1667/1669 [============================>.] - ETA: 0s - loss: 0.3576 - accuracy: 0.8634
# Epoch 23: val_accuracy did not improve from 0.89666
# 1669/1669 [==============================] - 9s 6ms/step - loss: 0.3578 - accuracy: 0.8634 - val_loss: 0.3403 - val_accuracy: 0.8678
# Epoch 24/200
# 1667/1669 [============================>.] - ETA: 0s - loss: 0.3567 - accuracy: 0.8653
# Epoch 24: val_accuracy did not improve from 0.89666
# 1669/1669 [==============================] - 9s 5ms/step - loss: 0.3568 - accuracy: 0.8653 - val_loss: 0.3344 - val_accuracy: 0.8700
# Epoch 25/200
# 1668/1669 [============================>.] - ETA: 0s - loss: 0.3542 - accuracy: 0.8673
# Epoch 25: val_accuracy did not improve from 0.89666
# 1669/1669 [==============================] - 9s 5ms/step - loss: 0.3543 - accuracy: 0.8672 - val_loss: 0.2942 - val_accuracy: 0.8930
# Epoch 26/200
# 1668/1669 [============================>.] - ETA: 0s - loss: 0.3470 - accuracy: 0.8691
# Epoch 26: val_accuracy did not improve from 0.89666
# 1669/1669 [==============================] - 9s 5ms/step - loss: 0.3470 - accuracy: 0.8691 - val_loss: 0.3491 - val_accuracy: 0.8648
# Epoch 27/200
# 1664/1669 [============================>.] - ETA: 0s - loss: 0.3476 - accuracy: 0.8697
# Epoch 27: val_accuracy did not improve from 0.89666
# 1669/1669 [==============================] - 9s 6ms/step - loss: 0.3477 - accuracy: 0.8697 - val_loss: 0.3207 - val_accuracy: 0.8749
# Epoch 28/200
# 1665/1669 [============================>.] - ETA: 0s - loss: 0.3468 - accuracy: 0.8691
# Epoch 28: val_accuracy improved from 0.89666 to 0.90593, saving model to best_model_spd.h5
# 1669/1669 [==============================] - 9s 5ms/step - loss: 0.3469 - accuracy: 0.8690 - val_loss: 0.2667 - val_accuracy: 0.9059
# Epoch 29/200
# 1665/1669 [============================>.] - ETA: 0s - loss: 0.3400 - accuracy: 0.8739
# Epoch 29: val_accuracy improved from 0.90593 to 0.90880, saving model to best_model_spd.h5
# 1669/1669 [==============================] - 9s 5ms/step - loss: 0.3400 - accuracy: 0.8739 - val_loss: 0.2535 - val_accuracy: 0.9088
# Epoch 30/200
# 1666/1669 [============================>.] - ETA: 0s - loss: 0.3370 - accuracy: 0.8739
# Epoch 30: val_accuracy did not improve from 0.90880
# 1669/1669 [==============================] - 9s 6ms/step - loss: 0.3370 - accuracy: 0.8739 - val_loss: 0.3335 - val_accuracy: 0.8670
# Epoch 31/200
# 1666/1669 [============================>.] - ETA: 0s - loss: 0.3377 - accuracy: 0.8753
# Epoch 31: val_accuracy did not improve from 0.90880
# 1669/1669 [==============================] - 9s 6ms/step - loss: 0.3379 - accuracy: 0.8753 - val_loss: 0.2889 - val_accuracy: 0.8957
# Epoch 32/200
# 1662/1669 [============================>.] - ETA: 0s - loss: 0.3389 - accuracy: 0.8736
# Epoch 32: val_accuracy did not improve from 0.90880
# 1669/1669 [==============================] - 9s 6ms/step - loss: 0.3391 - accuracy: 0.8734 - val_loss: 0.2964 - val_accuracy: 0.8882
# Epoch 33/200
# 1667/1669 [============================>.] - ETA: 0s - loss: 0.3350 - accuracy: 0.8767
# Epoch 33: val_accuracy did not improve from 0.90880
# 1669/1669 [==============================] - 9s 6ms/step - loss: 0.3350 - accuracy: 0.8767 - val_loss: 0.2979 - val_accuracy: 0.8936
# Epoch 34/200
# 1665/1669 [============================>.] - ETA: 0s - loss: 0.3342 - accuracy: 0.8785
# Epoch 34: val_accuracy did not improve from 0.90880
# 1669/1669 [==============================] - 9s 6ms/step - loss: 0.3342 - accuracy: 0.8786 - val_loss: 0.3481 - val_accuracy: 0.8594
# Epoch 35/200
# 1669/1669 [==============================] - ETA: 0s - loss: 0.3307 - accuracy: 0.8783
# Epoch 35: val_accuracy did not improve from 0.90880
# 1669/1669 [==============================] - 9s 6ms/step - loss: 0.3307 - accuracy: 0.8783 - val_loss: 0.3140 - val_accuracy: 0.8758
# Epoch 36/200
# 1663/1669 [============================>.] - ETA: 0s - loss: 0.3286 - accuracy: 0.8797
# Epoch 36: val_accuracy did not improve from 0.90880
# 1669/1669 [==============================] - 10s 6ms/step - loss: 0.3284 - accuracy: 0.8797 - val_loss: 0.3066 - val_accuracy: 0.8798
# Epoch 37/200
# 1664/1669 [============================>.] - ETA: 0s - loss: 0.3248 - accuracy: 0.8838
# Epoch 37: val_accuracy did not improve from 0.90880
# 1669/1669 [==============================] - 9s 6ms/step - loss: 0.3248 - accuracy: 0.8839 - val_loss: 0.2847 - val_accuracy: 0.8958
# Epoch 38/200
# 1666/1669 [============================>.] - ETA: 0s - loss: 0.3234 - accuracy: 0.8835
# Epoch 38: val_accuracy did not improve from 0.90880
# 1669/1669 [==============================] - 9s 6ms/step - loss: 0.3234 - accuracy: 0.8834 - val_loss: 0.2718 - val_accuracy: 0.9005
# Epoch 39/200
# 1665/1669 [============================>.] - ETA: 0s - loss: 0.3255 - accuracy: 0.8813
# Epoch 39: val_accuracy did not improve from 0.90880
# 1669/1669 [==============================] - 9s 6ms/step - loss: 0.3258 - accuracy: 0.8812 - val_loss: 0.3014 - val_accuracy: 0.8818
# Epoch 40/200
# 1668/1669 [============================>.] - ETA: 0s - loss: 0.3236 - accuracy: 0.8835
# Epoch 40: val_accuracy did not improve from 0.90880
# 1669/1669 [==============================] - 9s 5ms/step - loss: 0.3236 - accuracy: 0.8835 - val_loss: 0.3152 - val_accuracy: 0.8744
# Epoch 41/200
# 1661/1669 [============================>.] - ETA: 0s - loss: 0.3192 - accuracy: 0.8844
# Epoch 41: val_accuracy did not improve from 0.90880
# 1669/1669 [==============================] - 9s 6ms/step - loss: 0.3192 - accuracy: 0.8844 - val_loss: 0.2849 - val_accuracy: 0.8881
# Epoch 42/200
# 1665/1669 [============================>.] - ETA: 0s - loss: 0.3215 - accuracy: 0.8825
# Epoch 42: val_accuracy did not improve from 0.90880
# 1669/1669 [==============================] - 9s 5ms/step - loss: 0.3216 - accuracy: 0.8824 - val_loss: 0.2980 - val_accuracy: 0.8876
# Epoch 43/200
# 1665/1669 [============================>.] - ETA: 0s - loss: 0.3173 - accuracy: 0.8842
# Epoch 43: val_accuracy did not improve from 0.90880
# 1669/1669 [==============================] - 9s 6ms/step - loss: 0.3176 - accuracy: 0.8842 - val_loss: 0.2810 - val_accuracy: 0.8941
# Epoch 44/200
# 1665/1669 [============================>.] - ETA: 0s - loss: 0.3168 - accuracy: 0.8862
# Epoch 44: val_accuracy improved from 0.90880 to 0.91015, saving model to best_model_spd.h5
# 1669/1669 [==============================] - 10s 6ms/step - loss: 0.3169 - accuracy: 0.8862 - val_loss: 0.2545 - val_accuracy: 0.9101
# Epoch 45/200
# 1668/1669 [============================>.] - ETA: 0s - loss: 0.3160 - accuracy: 0.8873
# Epoch 45: val_accuracy did not improve from 0.91015
# 1669/1669 [==============================] - 10s 6ms/step - loss: 0.3159 - accuracy: 0.8873 - val_loss: 0.2593 - val_accuracy: 0.9071
# Epoch 46/200
# 1667/1669 [============================>.] - ETA: 0s - loss: 0.3191 - accuracy: 0.8863
# Epoch 46: val_accuracy did not improve from 0.91015
# 1669/1669 [==============================] - 9s 6ms/step - loss: 0.3191 - accuracy: 0.8863 - val_loss: 0.2967 - val_accuracy: 0.8845
# Epoch 47/200
# 1661/1669 [============================>.] - ETA: 0s - loss: 0.3147 - accuracy: 0.8856
# Epoch 47: val_accuracy improved from 0.91015 to 0.91167, saving model to best_model_spd.h5
# 1669/1669 [==============================] - 10s 6ms/step - loss: 0.3146 - accuracy: 0.8856 - val_loss: 0.2492 - val_accuracy: 0.9117
# Epoch 48/200
# 1662/1669 [============================>.] - ETA: 0s - loss: 0.3141 - accuracy: 0.8860
# Epoch 48: val_accuracy did not improve from 0.91167
# 1669/1669 [==============================] - 9s 6ms/step - loss: 0.3142 - accuracy: 0.8861 - val_loss: 0.2716 - val_accuracy: 0.9058
# Epoch 49/200
# 1662/1669 [============================>.] - ETA: 0s - loss: 0.3139 - accuracy: 0.8859
# Epoch 49: val_accuracy did not improve from 0.91167
# 1669/1669 [==============================] - 9s 5ms/step - loss: 0.3138 - accuracy: 0.8859 - val_loss: 0.3390 - val_accuracy: 0.8640
# Epoch 50/200
# 1661/1669 [============================>.] - ETA: 0s - loss: 0.3143 - accuracy: 0.8862
# Epoch 50: val_accuracy did not improve from 0.91167
# 1669/1669 [==============================] - 9s 6ms/step - loss: 0.3143 - accuracy: 0.8861 - val_loss: 0.2661 - val_accuracy: 0.9024
# Epoch 51/200
# 1664/1669 [============================>.] - ETA: 0s - loss: 0.3144 - accuracy: 0.8870
# Epoch 51: val_accuracy did not improve from 0.91167
# 1669/1669 [==============================] - 9s 5ms/step - loss: 0.3142 - accuracy: 0.8870 - val_loss: 0.2539 - val_accuracy: 0.9076
# Epoch 52/200
# 1662/1669 [============================>.] - ETA: 0s - loss: 0.3100 - accuracy: 0.8900
# Epoch 52: val_accuracy did not improve from 0.91167
# 1669/1669 [==============================] - 9s 5ms/step - loss: 0.3099 - accuracy: 0.8900 - val_loss: 0.2744 - val_accuracy: 0.8963
# Epoch 53/200
# 1667/1669 [============================>.] - ETA: 0s - loss: 0.3110 - accuracy: 0.8891
# Epoch 53: val_accuracy did not improve from 0.91167
# 1669/1669 [==============================] - 9s 6ms/step - loss: 0.3109 - accuracy: 0.8891 - val_loss: 0.2785 - val_accuracy: 0.8997
# Epoch 54/200
# 1663/1669 [============================>.] - ETA: 0s - loss: 0.3084 - accuracy: 0.8901
# Epoch 54: val_accuracy did not improve from 0.91167
# 1669/1669 [==============================] - 9s 5ms/step - loss: 0.3085 - accuracy: 0.8900 - val_loss: 0.2635 - val_accuracy: 0.9058
# Epoch 55/200
# 1667/1669 [============================>.] - ETA: 0s - loss: 0.3119 - accuracy: 0.8881
# Epoch 55: val_accuracy did not improve from 0.91167
# 1669/1669 [==============================] - 9s 6ms/step - loss: 0.3119 - accuracy: 0.8881 - val_loss: 0.2632 - val_accuracy: 0.9007
# Epoch 56/200
# 1669/1669 [==============================] - ETA: 0s - loss: 0.3058 - accuracy: 0.8899
# Epoch 56: val_accuracy did not improve from 0.91167
# 1669/1669 [==============================] - 9s 5ms/step - loss: 0.3058 - accuracy: 0.8899 - val_loss: 0.2575 - val_accuracy: 0.9021
# Epoch 57/200
# 1668/1669 [============================>.] - ETA: 0s - loss: 0.3114 - accuracy: 0.8911
# Epoch 57: val_accuracy did not improve from 0.91167
# 1669/1669 [==============================] - 9s 6ms/step - loss: 0.3114 - accuracy: 0.8912 - val_loss: 0.2404 - val_accuracy: 0.9115
# Epoch 58/200
# 1669/1669 [==============================] - ETA: 0s - loss: 0.3052 - accuracy: 0.8926
# Epoch 58: val_accuracy did not improve from 0.91167
# 1669/1669 [==============================] - 9s 5ms/step - loss: 0.3052 - accuracy: 0.8926 - val_loss: 0.2962 - val_accuracy: 0.8842
# Epoch 59/200
# 1665/1669 [============================>.] - ETA: 0s - loss: 0.3011 - accuracy: 0.8925
# Epoch 59: val_accuracy did not improve from 0.91167
# 1669/1669 [==============================] - 9s 6ms/step - loss: 0.3011 - accuracy: 0.8924 - val_loss: 0.2527 - val_accuracy: 0.9039
# Epoch 60/200
# 1661/1669 [============================>.] - ETA: 0s - loss: 0.3044 - accuracy: 0.8917
# Epoch 60: val_accuracy did not improve from 0.91167
# 1669/1669 [==============================] - 9s 6ms/step - loss: 0.3045 - accuracy: 0.8917 - val_loss: 0.2943 - val_accuracy: 0.8882
# Epoch 61/200
# 1666/1669 [============================>.] - ETA: 0s - loss: 0.3056 - accuracy: 0.8909
# Epoch 61: val_accuracy did not improve from 0.91167
# 1669/1669 [==============================] - 9s 6ms/step - loss: 0.3055 - accuracy: 0.8909 - val_loss: 0.3326 - val_accuracy: 0.8660
# Epoch 62/200
# 1663/1669 [============================>.] - ETA: 0s - loss: 0.3035 - accuracy: 0.8919
# Epoch 62: val_accuracy did not improve from 0.91167
# 1669/1669 [==============================] - 9s 5ms/step - loss: 0.3037 - accuracy: 0.8917 - val_loss: 0.2743 - val_accuracy: 0.8977
# Epoch 63/200
# 1666/1669 [============================>.] - ETA: 0s - loss: 0.2967 - accuracy: 0.8961
# Epoch 63: val_accuracy did not improve from 0.91167
# 1669/1669 [==============================] - 9s 6ms/step - loss: 0.2966 - accuracy: 0.8961 - val_loss: 0.2839 - val_accuracy: 0.8943
# Epoch 64/200
# 1666/1669 [============================>.] - ETA: 0s - loss: 0.2977 - accuracy: 0.8951
# Epoch 64: val_accuracy did not improve from 0.91167
# 1669/1669 [==============================] - 9s 6ms/step - loss: 0.2977 - accuracy: 0.8950 - val_loss: 0.2559 - val_accuracy: 0.9081
# Epoch 65/200
# 1668/1669 [============================>.] - ETA: 0s - loss: 0.2995 - accuracy: 0.8940
# Epoch 65: val_accuracy did not improve from 0.91167
# 1669/1669 [==============================] - 9s 6ms/step - loss: 0.2995 - accuracy: 0.8940 - val_loss: 0.2805 - val_accuracy: 0.8928
# Epoch 66/200
# 1665/1669 [============================>.] - ETA: 0s - loss: 0.3011 - accuracy: 0.8949
# Epoch 66: val_accuracy did not improve from 0.91167
# 1669/1669 [==============================] - 9s 6ms/step - loss: 0.3011 - accuracy: 0.8948 - val_loss: 0.2879 - val_accuracy: 0.8941
# Epoch 67/200
# 1667/1669 [============================>.] - ETA: 0s - loss: 0.2995 - accuracy: 0.8937
# Epoch 67: val_accuracy did not improve from 0.91167
# 1669/1669 [==============================] - 9s 6ms/step - loss: 0.2994 - accuracy: 0.8938 - val_loss: 0.2555 - val_accuracy: 0.9068
# Epoch 68/200
# 1666/1669 [============================>.] - ETA: 0s - loss: 0.2984 - accuracy: 0.8966
# Epoch 68: val_accuracy did not improve from 0.91167
# 1669/1669 [==============================] - 9s 6ms/step - loss: 0.2985 - accuracy: 0.8966 - val_loss: 0.2689 - val_accuracy: 0.8992
# Epoch 69/200
# 1660/1669 [============================>.] - ETA: 0s - loss: 0.2992 - accuracy: 0.8953
# Epoch 69: val_accuracy improved from 0.91167 to 0.91436, saving model to best_model_spd.h5
# 1669/1669 [==============================] - 9s 6ms/step - loss: 0.2989 - accuracy: 0.8955 - val_loss: 0.2486 - val_accuracy: 0.9144
# Epoch 70/200
# 1664/1669 [============================>.] - ETA: 0s - loss: 0.2986 - accuracy: 0.8950
# Epoch 70: val_accuracy did not improve from 0.91436
# 1669/1669 [==============================] - 9s 6ms/step - loss: 0.2985 - accuracy: 0.8951 - val_loss: 0.2630 - val_accuracy: 0.9056
# Epoch 71/200
# 1667/1669 [============================>.] - ETA: 0s - loss: 0.2945 - accuracy: 0.8957
# Epoch 71: val_accuracy did not improve from 0.91436
# 1669/1669 [==============================] - 9s 6ms/step - loss: 0.2945 - accuracy: 0.8957 - val_loss: 0.2748 - val_accuracy: 0.8955
# Epoch 72/200
# 1665/1669 [============================>.] - ETA: 0s - loss: 0.2962 - accuracy: 0.8945
# Epoch 72: val_accuracy did not improve from 0.91436
# 1669/1669 [==============================] - 9s 6ms/step - loss: 0.2961 - accuracy: 0.8946 - val_loss: 0.2759 - val_accuracy: 0.8970
# Epoch 73/200
# 1665/1669 [============================>.] - ETA: 0s - loss: 0.2919 - accuracy: 0.8980
# Epoch 73: val_accuracy did not improve from 0.91436
# 1669/1669 [==============================] - 17s 10ms/step - loss: 0.2918 - accuracy: 0.8981 - val_loss: 0.2930 - val_accuracy: 0.8889
# Epoch 74/200
# 1662/1669 [============================>.] - ETA: 0s - loss: 0.2940 - accuracy: 0.8978
# Epoch 74: val_accuracy did not improve from 0.91436
# 1669/1669 [==============================] - 9s 6ms/step - loss: 0.2940 - accuracy: 0.8978 - val_loss: 0.2795 - val_accuracy: 0.8970
# Epoch 75/200
# 1666/1669 [============================>.] - ETA: 0s - loss: 0.2972 - accuracy: 0.8947
# Epoch 75: val_accuracy did not improve from 0.91436
# 1669/1669 [==============================] - 10s 6ms/step - loss: 0.2972 - accuracy: 0.8947 - val_loss: 0.3503 - val_accuracy: 0.8576
# Epoch 76/200
# 1666/1669 [============================>.] - ETA: 0s - loss: 0.2962 - accuracy: 0.8953
# Epoch 76: val_accuracy improved from 0.91436 to 0.92633, saving model to best_model_spd.h5
# 1669/1669 [==============================] - 10s 6ms/step - loss: 0.2961 - accuracy: 0.8953 - val_loss: 0.2233 - val_accuracy: 0.9263
# Epoch 77/200
# 1665/1669 [============================>.] - ETA: 0s - loss: 0.2956 - accuracy: 0.8949
# Epoch 77: val_accuracy did not improve from 0.92633
# 1669/1669 [==============================] - 9s 6ms/step - loss: 0.2955 - accuracy: 0.8950 - val_loss: 0.3200 - val_accuracy: 0.8780
# Epoch 78/200
# 1663/1669 [============================>.] - ETA: 0s - loss: 0.2896 - accuracy: 0.8987
# Epoch 78: val_accuracy did not improve from 0.92633
# 1669/1669 [==============================] - 10s 6ms/step - loss: 0.2896 - accuracy: 0.8986 - val_loss: 0.2449 - val_accuracy: 0.9120
# Epoch 79/200
# 1665/1669 [============================>.] - ETA: 0s - loss: 0.2948 - accuracy: 0.8983
# Epoch 79: val_accuracy did not improve from 0.92633
# 1669/1669 [==============================] - 10s 6ms/step - loss: 0.2948 - accuracy: 0.8983 - val_loss: 0.3099 - val_accuracy: 0.8788
# Epoch 80/200
# 1662/1669 [============================>.] - ETA: 0s - loss: 0.2944 - accuracy: 0.8972
# Epoch 80: val_accuracy did not improve from 0.92633
# 1669/1669 [==============================] - 10s 6ms/step - loss: 0.2947 - accuracy: 0.8972 - val_loss: 0.2809 - val_accuracy: 0.8951
# Epoch 81/200
# 1667/1669 [============================>.] - ETA: 0s - loss: 0.2933 - accuracy: 0.8973
# Epoch 81: val_accuracy did not improve from 0.92633
# 1669/1669 [==============================] - 10s 6ms/step - loss: 0.2933 - accuracy: 0.8973 - val_loss: 0.2451 - val_accuracy: 0.9144
# Epoch 82/200
# 1665/1669 [============================>.] - ETA: 0s - loss: 0.2905 - accuracy: 0.8983
# Epoch 82: val_accuracy did not improve from 0.92633
# 1669/1669 [==============================] - 9s 6ms/step - loss: 0.2907 - accuracy: 0.8982 - val_loss: 0.2934 - val_accuracy: 0.8871
# Epoch 83/200
# 1662/1669 [============================>.] - ETA: 0s - loss: 0.2924 - accuracy: 0.8984
# Epoch 83: val_accuracy did not improve from 0.92633
# 1669/1669 [==============================] - 10s 6ms/step - loss: 0.2924 - accuracy: 0.8984 - val_loss: 0.2717 - val_accuracy: 0.8994
# Epoch 84/200
# 1663/1669 [============================>.] - ETA: 0s - loss: 0.2912 - accuracy: 0.9001
# Epoch 84: val_accuracy did not improve from 0.92633
# 1669/1669 [==============================] - 11s 7ms/step - loss: 0.2912 - accuracy: 0.9001 - val_loss: 0.2784 - val_accuracy: 0.8935
# Epoch 85/200
# 1661/1669 [============================>.] - ETA: 0s - loss: 0.2896 - accuracy: 0.8997
# Epoch 85: val_accuracy did not improve from 0.92633
# 1669/1669 [==============================] - 10s 6ms/step - loss: 0.2895 - accuracy: 0.8998 - val_loss: 0.2878 - val_accuracy: 0.8918
# Epoch 86/200
# 1659/1669 [============================>.] - ETA: 0s - loss: 0.2951 - accuracy: 0.8983
# Epoch 86: val_accuracy did not improve from 0.92633
# 1669/1669 [==============================] - 10s 6ms/step - loss: 0.2951 - accuracy: 0.8982 - val_loss: 0.2660 - val_accuracy: 0.8989
# Epoch 87/200
# 1660/1669 [============================>.] - ETA: 0s - loss: 0.2927 - accuracy: 0.8983
# Epoch 87: val_accuracy did not improve from 0.92633
# 1669/1669 [==============================] - 9s 6ms/step - loss: 0.2926 - accuracy: 0.8984 - val_loss: 0.2559 - val_accuracy: 0.9088
# Epoch 88/200
# 1668/1669 [============================>.] - ETA: 0s - loss: 0.2886 - accuracy: 0.9000
# Epoch 88: val_accuracy did not improve from 0.92633
# 1669/1669 [==============================] - 9s 6ms/step - loss: 0.2886 - accuracy: 0.9000 - val_loss: 0.2832 - val_accuracy: 0.8918
# Epoch 89/200
# 1662/1669 [============================>.] - ETA: 0s - loss: 0.2886 - accuracy: 0.9006
# Epoch 89: val_accuracy did not improve from 0.92633
# 1669/1669 [==============================] - 10s 6ms/step - loss: 0.2884 - accuracy: 0.9007 - val_loss: 0.2431 - val_accuracy: 0.9090
# Epoch 90/200
# 1662/1669 [============================>.] - ETA: 0s - loss: 0.2882 - accuracy: 0.9007
# Epoch 90: val_accuracy did not improve from 0.92633
# 1669/1669 [==============================] - 9s 6ms/step - loss: 0.2883 - accuracy: 0.9007 - val_loss: 0.2720 - val_accuracy: 0.9009
# Epoch 91/200
# 1665/1669 [============================>.] - ETA: 0s - loss: 0.2870 - accuracy: 0.9007
# Epoch 91: val_accuracy did not improve from 0.92633
# 1669/1669 [==============================] - 10s 6ms/step - loss: 0.2869 - accuracy: 0.9008 - val_loss: 0.2674 - val_accuracy: 0.9066
# Epoch 92/200
# 1667/1669 [============================>.] - ETA: 0s - loss: 0.2882 - accuracy: 0.8991
# Epoch 92: val_accuracy did not improve from 0.92633
# 1669/1669 [==============================] - 10s 6ms/step - loss: 0.2882 - accuracy: 0.8992 - val_loss: 0.2503 - val_accuracy: 0.9061
# Epoch 93/200
# 1666/1669 [============================>.] - ETA: 0s - loss: 0.2876 - accuracy: 0.8987
# Epoch 93: val_accuracy did not improve from 0.92633
# 1669/1669 [==============================] - 9s 6ms/step - loss: 0.2876 - accuracy: 0.8987 - val_loss: 0.2405 - val_accuracy: 0.9128
# Epoch 94/200
# 1662/1669 [============================>.] - ETA: 0s - loss: 0.2889 - accuracy: 0.8998
# Epoch 94: val_accuracy did not improve from 0.92633
# 1669/1669 [==============================] - 10s 6ms/step - loss: 0.2889 - accuracy: 0.8998 - val_loss: 0.2562 - val_accuracy: 0.9058
# Epoch 95/200
# 1664/1669 [============================>.] - ETA: 0s - loss: 0.2865 - accuracy: 0.9004
# Epoch 95: val_accuracy did not improve from 0.92633
# 1669/1669 [==============================] - 10s 6ms/step - loss: 0.2865 - accuracy: 0.9003 - val_loss: 0.2721 - val_accuracy: 0.8953
# Epoch 96/200
# 1666/1669 [============================>.] - ETA: 0s - loss: 0.2858 - accuracy: 0.9008
# Epoch 96: val_accuracy did not improve from 0.92633
# 1669/1669 [==============================] - 10s 6ms/step - loss: 0.2860 - accuracy: 0.9007 - val_loss: 0.2734 - val_accuracy: 0.8948
# Epoch 96: early stopping

# %%
from matplotlib import pyplot as plt
#plot training and validation accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
#plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train','validation'], loc='lower right')
plt.savefig('accuracy_curve_spd_balanced_smote.png')
plt.show()

# %%
#plot training loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.plot()
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train','validation'], loc='upper right')
plt.savefig('loss_curve_spd_balanced_smote.png')
plt.show()

# %%
# load the saved model
saved_model = load_model('best_model_spd.h5')
# evaluate the model
#_, train_acc = saved_model.evaluate(trainX, trainy, verbose=0)
#_, test_acc = saved_model.evaluate(testX, testy, verbose=0)
#print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))

# %%
probabilities = saved_model.predict(testX2)
predicted_classes = probabilities >= 0.5
predicted_classes = predicted_classes.astype(int)
acc, sensitivity, specificity, precision, MCC = calculate_performance(len(y_test),predicted_classes , y_test)

print('Result Summary:')
print('------------------------------')
print('accuracy: ',acc, end =", ")
print('sensitivity: ',sensitivity, end =", ")
print('specificity: ',specificity, end =" ,")
print('precision: ',precision, end =" ,")
print('MCC : ',MCC)
# Out:
# Result Summary:
# ------------------------------
# accuracy:  0.9263317599460553, sensitivity:  0.9779808890735355, specificity:  0.8910638297872341 ,precision:  0.8597516435354273 ,MCC :  0.8560035242805009

# %%
def get_evolutionary_model():
    ### Head-1:
    input1 = Input(shape=trainX1[0].shape)

    x = Conv1D(filters=32, kernel_size=3, padding='same', kernel_regularizer=l2(l=0.01))(input1)
    #x = BatchNormalization()(x)
    x = Dropout(rate=0.5)(x)

    #x = Conv1D(filters=8, kernel_size=3, padding='same', activation='relu', kernel_regularizer=l2(l=0.01))(x)
    #x = BatchNormalization()(x)
    #x = Dropout(rate=0.50)(x)

    head1 = Flatten()(x)

    z= Dense(units=256, activation='relu',)(head1)
    z = Dropout(rate=0.5)(z)

    z = Dense(units=64, activation='relu',)(z)
    z = Dropout(rate=0.5)(z)

    z = Dense(units=16, activation='relu',)(z)
    z = Dropout(rate=0.5)(z)
    
    z = Dense(1, activation='sigmoid')(z)

    return Model(inputs=[input1], outputs=[z])
#end-def

# %%
model = get_evolutionary_model()
model.summary()
plot_model(model, to_file='model-pssm.png', show_shapes=True, show_layer_names=False, expand_nested=True)
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 21, 20)]          0
#
#  conv1d_1 (Conv1D)           (None, 21, 32)            1952
#
#  dropout_4 (Dropout)         (None, 21, 32)            0
#
#  flatten_1 (Flatten)         (None, 672)               0
#
#  dense_4 (Dense)             (None, 256)               172288
#
#  dropout_5 (Dropout)         (None, 256)               0
#
#  dense_5 (Dense)             (None, 64)                16448
#
#  dropout_6 (Dropout)         (None, 64)                0
#
#  dense_6 (Dense)             (None, 16)                1040
#
#  dropout_7 (Dropout)         (None, 16)                0
#
#  dense_7 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 191,745
# Trainable params: 191,745
# Non-trainable params: 0
# _________________________________________________________________

# %%
# patient early stopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=20)
# save the best model
mc = ModelCheckpoint('best_model_pssm.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)
# Compile Model:
#model = Ne()
model.compile(optimizer=Adam(learning_rate=0.0005),
              loss='binary_crossentropy',
              metrics=['accuracy'])

# Run Model:
history = model.fit(x=trainX1, y= y_train, validation_data=(testX1, y_test), batch_size=32, epochs=200, verbose=1, callbacks=[es,mc])
# Out:
# Epoch 1/200
# 1667/1669 [============================>.] - ETA: 0s - loss: 0.6864 - accuracy: 0.6340
# Epoch 1: val_accuracy improved from -inf to 0.66976, saving model to best_model_pssm.h5
# 1669/1669 [==============================] - 10s 6ms/step - loss: 0.6863 - accuracy: 0.6341 - val_loss: 0.6238 - val_accuracy: 0.6698
# Epoch 2/200
# 1663/1669 [============================>.] - ETA: 0s - loss: 0.5619 - accuracy: 0.7353
# Epoch 2: val_accuracy improved from 0.66976 to 0.73517, saving model to best_model_pssm.h5
# 1669/1669 [==============================] - 9s 6ms/step - loss: 0.5616 - accuracy: 0.7356 - val_loss: 0.5432 - val_accuracy: 0.7352
# Epoch 3/200
# 1665/1669 [============================>.] - ETA: 0s - loss: 0.4866 - accuracy: 0.7913
# Epoch 3: val_accuracy did not improve from 0.73517
# 1669/1669 [==============================] - 11s 7ms/step - loss: 0.4863 - accuracy: 0.7915 - val_loss: 0.6430 - val_accuracy: 0.6962
# Epoch 4/200
# 1662/1669 [============================>.] - ETA: 0s - loss: 0.4347 - accuracy: 0.8210
# Epoch 4: val_accuracy did not improve from 0.73517
# 1669/1669 [==============================] - 10s 6ms/step - loss: 0.4347 - accuracy: 0.8209 - val_loss: 0.7315 - val_accuracy: 0.6853
# Epoch 5/200
# 1662/1669 [============================>.] - ETA: 0s - loss: 0.4063 - accuracy: 0.8377
# Epoch 5: val_accuracy improved from 0.73517 to 0.74073, saving model to best_model_pssm.h5
# 1669/1669 [==============================] - 11s 7ms/step - loss: 0.4062 - accuracy: 0.8377 - val_loss: 0.6351 - val_accuracy: 0.7407
# Epoch 6/200
# 1664/1669 [============================>.] - ETA: 0s - loss: 0.3921 - accuracy: 0.8478
# Epoch 6: val_accuracy did not improve from 0.74073
# 1669/1669 [==============================] - 12s 7ms/step - loss: 0.3920 - accuracy: 0.8478 - val_loss: 0.7047 - val_accuracy: 0.7107
# Epoch 7/200
# 1662/1669 [============================>.] - ETA: 0s - loss: 0.3708 - accuracy: 0.8592
# Epoch 7: val_accuracy improved from 0.74073 to 0.74208, saving model to best_model_pssm.h5
# 1669/1669 [==============================] - 10s 6ms/step - loss: 0.3707 - accuracy: 0.8593 - val_loss: 0.6381 - val_accuracy: 0.7421
# Epoch 8/200
# 1664/1669 [============================>.] - ETA: 0s - loss: 0.3636 - accuracy: 0.8656
# Epoch 8: val_accuracy did not improve from 0.74208
# 1669/1669 [==============================] - 11s 6ms/step - loss: 0.3640 - accuracy: 0.8654 - val_loss: 0.6429 - val_accuracy: 0.7372
# Epoch 9/200
# 1660/1669 [============================>.] - ETA: 0s - loss: 0.3502 - accuracy: 0.8704
# Epoch 9: val_accuracy improved from 0.74208 to 0.76686, saving model to best_model_pssm.h5
# 1669/1669 [==============================] - 13s 8ms/step - loss: 0.3501 - accuracy: 0.8706 - val_loss: 0.5884 - val_accuracy: 0.7669
# Epoch 10/200
# 1661/1669 [============================>.] - ETA: 0s - loss: 0.3473 - accuracy: 0.8727
# Epoch 10: val_accuracy improved from 0.76686 to 0.78557, saving model to best_model_pssm.h5
# 1669/1669 [==============================] - 9s 5ms/step - loss: 0.3474 - accuracy: 0.8727 - val_loss: 0.5300 - val_accuracy: 0.7856
# Epoch 11/200
# 1664/1669 [============================>.] - ETA: 0s - loss: 0.3414 - accuracy: 0.8756
# Epoch 11: val_accuracy improved from 0.78557 to 0.81945, saving model to best_model_pssm.h5
# 1669/1669 [==============================] - 10s 6ms/step - loss: 0.3415 - accuracy: 0.8757 - val_loss: 0.4623 - val_accuracy: 0.8195
# Epoch 12/200
# 1669/1669 [==============================] - ETA: 0s - loss: 0.3240 - accuracy: 0.8820
# Epoch 12: val_accuracy did not improve from 0.81945
# 1669/1669 [==============================] - 10s 6ms/step - loss: 0.3240 - accuracy: 0.8820 - val_loss: 0.6082 - val_accuracy: 0.7623
# Epoch 13/200
# 1663/1669 [============================>.] - ETA: 0s - loss: 0.3241 - accuracy: 0.8810
# Epoch 13: val_accuracy did not improve from 0.81945
# 1669/1669 [==============================] - 12s 7ms/step - loss: 0.3244 - accuracy: 0.8809 - val_loss: 0.5592 - val_accuracy: 0.7782
# Epoch 14/200
# 1668/1669 [============================>.] - ETA: 0s - loss: 0.3222 - accuracy: 0.8842
# Epoch 14: val_accuracy did not improve from 0.81945
# 1669/1669 [==============================] - 9s 5ms/step - loss: 0.3222 - accuracy: 0.8842 - val_loss: 0.6052 - val_accuracy: 0.7611
# Epoch 15/200
# 1661/1669 [============================>.] - ETA: 0s - loss: 0.3175 - accuracy: 0.8844
# Epoch 15: val_accuracy did not improve from 0.81945
# 1669/1669 [==============================] - 9s 6ms/step - loss: 0.3173 - accuracy: 0.8845 - val_loss: 0.6977 - val_accuracy: 0.7254
# Epoch 16/200
# 1665/1669 [============================>.] - ETA: 0s - loss: 0.3105 - accuracy: 0.8903
# Epoch 16: val_accuracy did not improve from 0.81945
# 1669/1669 [==============================] - 9s 6ms/step - loss: 0.3105 - accuracy: 0.8903 - val_loss: 0.5506 - val_accuracy: 0.7803
# Epoch 17/200
# 1666/1669 [============================>.] - ETA: 0s - loss: 0.3049 - accuracy: 0.8921
# Epoch 17: val_accuracy did not improve from 0.81945
# 1669/1669 [==============================] - 9s 6ms/step - loss: 0.3050 - accuracy: 0.8921 - val_loss: 0.5789 - val_accuracy: 0.7726
# Epoch 18/200
# 1669/1669 [==============================] - ETA: 0s - loss: 0.3038 - accuracy: 0.8942
# Epoch 18: val_accuracy did not improve from 0.81945
# 1669/1669 [==============================] - 10s 6ms/step - loss: 0.3038 - accuracy: 0.8942 - val_loss: 0.5438 - val_accuracy: 0.7900
# Epoch 19/200
# 1665/1669 [============================>.] - ETA: 0s - loss: 0.2989 - accuracy: 0.8946
# Epoch 19: val_accuracy did not improve from 0.81945
# 1669/1669 [==============================] - 10s 6ms/step - loss: 0.2989 - accuracy: 0.8946 - val_loss: 0.5053 - val_accuracy: 0.8073
# Epoch 20/200
# 1661/1669 [============================>.] - ETA: 0s - loss: 0.2944 - accuracy: 0.8968
# Epoch 20: val_accuracy did not improve from 0.81945
# 1669/1669 [==============================] - 9s 6ms/step - loss: 0.2942 - accuracy: 0.8970 - val_loss: 0.4881 - val_accuracy: 0.8129
# Epoch 21/200
# 1661/1669 [============================>.] - ETA: 0s - loss: 0.2895 - accuracy: 0.8996
# Epoch 21: val_accuracy did not improve from 0.81945
# 1669/1669 [==============================] - 10s 6ms/step - loss: 0.2894 - accuracy: 0.8996 - val_loss: 0.5634 - val_accuracy: 0.7847
# Epoch 22/200
# 1664/1669 [============================>.] - ETA: 0s - loss: 0.2874 - accuracy: 0.9010
# Epoch 22: val_accuracy improved from 0.81945 to 0.85722, saving model to best_model_pssm.h5
# 1669/1669 [==============================] - 10s 6ms/step - loss: 0.2873 - accuracy: 0.9009 - val_loss: 0.3795 - val_accuracy: 0.8572
# Epoch 23/200
# 1665/1669 [============================>.] - ETA: 0s - loss: 0.2919 - accuracy: 0.8995
# Epoch 23: val_accuracy did not improve from 0.85722
# 1669/1669 [==============================] - 10s 6ms/step - loss: 0.2920 - accuracy: 0.8996 - val_loss: 0.4972 - val_accuracy: 0.8006
# Epoch 24/200
# 1662/1669 [============================>.] - ETA: 0s - loss: 0.2870 - accuracy: 0.9020
# Epoch 24: val_accuracy did not improve from 0.85722
# 1669/1669 [==============================] - 10s 6ms/step - loss: 0.2871 - accuracy: 0.9019 - val_loss: 0.4603 - val_accuracy: 0.8228
# Epoch 25/200
# 1667/1669 [============================>.] - ETA: 0s - loss: 0.2866 - accuracy: 0.9017
# Epoch 25: val_accuracy did not improve from 0.85722
# 1669/1669 [==============================] - 10s 6ms/step - loss: 0.2868 - accuracy: 0.9016 - val_loss: 0.5669 - val_accuracy: 0.7744
# Epoch 26/200
# 1669/1669 [==============================] - ETA: 0s - loss: 0.2806 - accuracy: 0.9059
# Epoch 26: val_accuracy did not improve from 0.85722
# 1669/1669 [==============================] - 10s 6ms/step - loss: 0.2806 - accuracy: 0.9059 - val_loss: 0.4530 - val_accuracy: 0.8281
# Epoch 27/200
# 1664/1669 [============================>.] - ETA: 0s - loss: 0.2807 - accuracy: 0.9068
# Epoch 27: val_accuracy did not improve from 0.85722
# 1669/1669 [==============================] - 10s 6ms/step - loss: 0.2804 - accuracy: 0.9069 - val_loss: 0.4011 - val_accuracy: 0.8479
# Epoch 28/200
# 1662/1669 [============================>.] - ETA: 0s - loss: 0.2777 - accuracy: 0.9048
# Epoch 28: val_accuracy did not improve from 0.85722
# 1669/1669 [==============================] - 10s 6ms/step - loss: 0.2775 - accuracy: 0.9049 - val_loss: 0.5099 - val_accuracy: 0.8006
# Epoch 29/200
# 1660/1669 [============================>.] - ETA: 0s - loss: 0.2752 - accuracy: 0.9082
# Epoch 29: val_accuracy did not improve from 0.85722
# 1669/1669 [==============================] - 9s 6ms/step - loss: 0.2752 - accuracy: 0.9081 - val_loss: 0.6489 - val_accuracy: 0.7466
# Epoch 30/200
# 1666/1669 [============================>.] - ETA: 0s - loss: 0.2741 - accuracy: 0.9077
# Epoch 30: val_accuracy did not improve from 0.85722
# 1669/1669 [==============================] - 9s 6ms/step - loss: 0.2741 - accuracy: 0.9076 - val_loss: 0.4443 - val_accuracy: 0.8282
# Epoch 31/200
# 1668/1669 [============================>.] - ETA: 0s - loss: 0.2711 - accuracy: 0.9070
# Epoch 31: val_accuracy did not improve from 0.85722
# 1669/1669 [==============================] - 10s 6ms/step - loss: 0.2710 - accuracy: 0.9070 - val_loss: 0.5435 - val_accuracy: 0.7916
# Epoch 32/200
# 1668/1669 [============================>.] - ETA: 0s - loss: 0.2712 - accuracy: 0.9085
# Epoch 32: val_accuracy did not improve from 0.85722
# 1669/1669 [==============================] - 9s 6ms/step - loss: 0.2712 - accuracy: 0.9085 - val_loss: 0.4409 - val_accuracy: 0.8297
# Epoch 33/200
# 1663/1669 [============================>.] - ETA: 0s - loss: 0.2661 - accuracy: 0.9110
# Epoch 33: val_accuracy did not improve from 0.85722
# 1669/1669 [==============================] - 11s 7ms/step - loss: 0.2663 - accuracy: 0.9109 - val_loss: 0.5040 - val_accuracy: 0.8045
# Epoch 34/200
# 1664/1669 [============================>.] - ETA: 0s - loss: 0.2682 - accuracy: 0.9106
# Epoch 34: val_accuracy did not improve from 0.85722
# 1669/1669 [==============================] - 9s 6ms/step - loss: 0.2682 - accuracy: 0.9106 - val_loss: 0.5151 - val_accuracy: 0.7948
# Epoch 35/200
# 1669/1669 [==============================] - ETA: 0s - loss: 0.2700 - accuracy: 0.9102
# Epoch 35: val_accuracy did not improve from 0.85722
# 1669/1669 [==============================] - 9s 6ms/step - loss: 0.2700 - accuracy: 0.9102 - val_loss: 0.5546 - val_accuracy: 0.7911
# Epoch 36/200
# 1669/1669 [==============================] - ETA: 0s - loss: 0.2663 - accuracy: 0.9120
# Epoch 36: val_accuracy did not improve from 0.85722
# 1669/1669 [==============================] - 9s 6ms/step - loss: 0.2663 - accuracy: 0.9120 - val_loss: 0.4277 - val_accuracy: 0.8365
# Epoch 37/200
# 1660/1669 [============================>.] - ETA: 0s - loss: 0.2666 - accuracy: 0.9120
# Epoch 37: val_accuracy did not improve from 0.85722
# 1669/1669 [==============================] - 10s 6ms/step - loss: 0.2665 - accuracy: 0.9121 - val_loss: 0.4117 - val_accuracy: 0.8469
# Epoch 38/200
# 1666/1669 [============================>.] - ETA: 0s - loss: 0.2670 - accuracy: 0.9108
# Epoch 38: val_accuracy did not improve from 0.85722
# 1669/1669 [==============================] - 10s 6ms/step - loss: 0.2670 - accuracy: 0.9109 - val_loss: 0.5574 - val_accuracy: 0.7802
# Epoch 39/200
# 1661/1669 [============================>.] - ETA: 0s - loss: 0.2639 - accuracy: 0.9115
# Epoch 39: val_accuracy did not improve from 0.85722
# 1669/1669 [==============================] - 10s 6ms/step - loss: 0.2637 - accuracy: 0.9116 - val_loss: 0.4201 - val_accuracy: 0.8461
# Epoch 40/200
# 1669/1669 [==============================] - ETA: 0s - loss: 0.2590 - accuracy: 0.9132
# Epoch 40: val_accuracy did not improve from 0.85722
# 1669/1669 [==============================] - 10s 6ms/step - loss: 0.2590 - accuracy: 0.9132 - val_loss: 0.4123 - val_accuracy: 0.8560
# Epoch 41/200
# 1664/1669 [============================>.] - ETA: 0s - loss: 0.2595 - accuracy: 0.9152
# Epoch 41: val_accuracy did not improve from 0.85722
# 1669/1669 [==============================] - 10s 6ms/step - loss: 0.2596 - accuracy: 0.9153 - val_loss: 0.4583 - val_accuracy: 0.8223
# Epoch 42/200
# 1664/1669 [============================>.] - ETA: 0s - loss: 0.2563 - accuracy: 0.9161
# Epoch 42: val_accuracy did not improve from 0.85722
# 1669/1669 [==============================] - 10s 6ms/step - loss: 0.2564 - accuracy: 0.9160 - val_loss: 0.5268 - val_accuracy: 0.8070
# Epoch 42: early stopping

# %%
from matplotlib import pyplot as plt
#plot training and validation accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
#plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train','validation'], loc='lower right')
plt.savefig('accuracy_curve_pssm_balanced_smote.png')
plt.show()

# %%
#plot training loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.plot()
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train','validation'], loc='upper right')
plt.savefig('loss_curve_pssm_balanced_smote.png')
plt.show()

# %%
saved_model = load_model('best_model_pssm.h5')
probabilities = saved_model.predict(testX1)
predicted_classes = probabilities >= 0.5
predicted_classes = predicted_classes.astype(int)
acc, sensitivity, specificity, precision, MCC = calculate_performance(len(y_test),predicted_classes , y_test)

print('Result Summary:')
print('------------------------------')
print('accuracy: ',acc, end =", ")
print('sensitivity: ',sensitivity, end =", ")
print('specificity: ',specificity, end =" ,")
print('precision: ',precision, end =" ,")
print('MCC : ',MCC)
# Out:
# Result Summary:
# ------------------------------
# accuracy:  0.8572151045178692, sensitivity:  0.9825508932280848, specificity:  0.7716312056737589 ,precision:  0.7460567823343849 ,MCC :  0.7424246064772515

# %%
# !pip install rotation-forest
from sklearn.ensemble import AdaBoostClassifier, RandomForestClassifier,GradientBoostingClassifier
from rotation_forest import RotationForestClassifier
#ml_model = RandomForestClassifier(n_estimators=100, bootstrap=False, random_state=47, verbose=1)
ml_model = RotationForestClassifier(n_estimators=100, random_state=47, verbose=4, n_jobs=-2)
ml_model.fit(x_train[:, 420: ],y_train )
y_predict = ml_model.predict(x_test[:,420:])
# Out:
# Collecting rotation-forest
#   Downloading rotation_forest-1.0.tar.gz (6.3 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from rotation-forest) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from rotation-forest) (1.4.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from rotation-forest) (1.0.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->rotation-forest) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->rotation-forest) (1.1.0)
# Building wheels for collected packages: rotation-forest
#   Building wheel for rotation-forest (setup.py) ... done
#   Created wheel for rotation-forest: filename=rotation_forest-1.0-py3-none-any.whl size=7002 sha256=0cd469f237899cb321ef9c5875d9f851cd83ac839726786caf08e71e9f010a63
#   Stored in directory: /root/.cache/pip/wheels/1a/d7/d5/e657bdbc7feafd9f8808611ad808bcffbcb50c71dd93b9e8e4
# Successfully built rotation-forest
# Installing collected packages: rotation-forest
# Successfully installed rotation-forest-1.0
# [Parallel(n_jobs=-2)]: Using backend SequentialBackend with 1 concurrent workers.
# building tree 1 of 100
# [Parallel(n_jobs=-2)]: Done   1 out of   1 | elapsed:   28.1s remaining:    0.0s
# building tree 2 of 100
# [Parallel(n_jobs=-2)]: Done   2 out of   2 | elapsed:   56.5s remaining:    0.0s
# building tree 3 of 100
# [Parallel(n_jobs=-2)]: Done   3 out of   3 | elapsed:  1.4min remaining:    0.0s
# building tree 4 of 100
# building tree 5 of 100
# building tree 6 of 100
# building tree 7 of 100
# building tree 8 of 100
# building tree 9 of 100
# building tree 10 of 100
# building tree 11 of 100
# building tree 12 of 100
# building tree 13 of 100
# building tree 14 of 100
# building tree 15 of 100
# building tree 16 of 100
# building tree 17 of 100
# building tree 18 of 100
# building tree 19 of 100
# building tree 20 of 100
# building tree 21 of 100
# building tree 22 of 100
# building tree 23 of 100
# building tree 24 of 100
# building tree 25 of 100
# building tree 26 of 100
# building tree 27 of 100
# building tree 28 of 100
# building tree 29 of 100
# building tree 30 of 100
# building tree 31 of 100
# building tree 32 of 100
# building tree 33 of 100
# building tree 34 of 100
# building tree 35 of 100
# building tree 36 of 100
# building tree 37 of 100
# building tree 38 of 100
# building tree 39 of 100
# building tree 40 of 100
# building tree 41 of 100
# building tree 42 of 100
# building tree 43 of 100
# building tree 44 of 100
# building tree 45 of 100
# building tree 46 of 100
# building tree 47 of 100
# building tree 48 of 100
# building tree 49 of 100
# building tree 50 of 100
# building tree 51 of 100
# building tree 52 of 100
# building tree 53 of 100
# building tree 54 of 100
# building tree 55 of 100
# building tree 56 of 100
# building tree 57 of 100
# building tree 58 of 100
# building tree 59 of 100
# building tree 60 of 100
# building tree 61 of 100
# building tree 62 of 100
# building tree 63 of 100
# building tree 64 of 100
# building tree 65 of 100
# building tree 66 of 100
# building tree 67 of 100
# building tree 68 of 100
# building tree 69 of 100
# building tree 70 of 100
# building tree 71 of 100
# building tree 72 of 100
# building tree 73 of 100
# building tree 74 of 100
# building tree 75 of 100
# building tree 76 of 100
# building tree 77 of 100
# building tree 78 of 100
# building tree 79 of 100
# building tree 80 of 100
# building tree 81 of 100
# building tree 82 of 100
# building tree 83 of 100
# building tree 84 of 100
# building tree 85 of 100
# building tree 86 of 100
# building tree 87 of 100
# building tree 88 of 100
# building tree 89 of 100
# building tree 90 of 100
# building tree 91 of 100
# building tree 92 of 100
# building tree 93 of 100
# building tree 94 of 100
# building tree 95 of 100
# building tree 96 of 100
# building tree 97 of 100
# building tree 98 of 100
# building tree 99 of 100
# building tree 100 of 100
# [Parallel(n_jobs=-2)]: Done 100 out of 100 | elapsed: 47.0min finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    2.5s finished

# %%
y_predict
# Out:
# array([1, 1, 0, ..., 1, 1, 1], dtype=int32)

# %%
model.save("model_pssm_conv1_train_balanced.h5")

# %%
from tensorflow.keras.layers import Layer, InputSpec
def squeeze_excite_block(self, x):
	# store the input
	shortcut = x
	# calculate the number of filters the input has
	filters = x.shape[-1]
	# the squeeze operation reduces the input dimensionality
	# here we do a global average pooling across the filters, which
	# reduces the input to a 1D vector
	x = GlobalAveragePooling2D(keepdims=True)(x)
	# reduce the number of filters (1 x 1 x C/r)
	x = Dense(filters // self.ratio, activation="relu",
		kernel_initializer="he_normal", use_bias=False)(x)
	
	# the excitation operation restores the input dimensionality
	x = Dense(filters, activation="sigmoid",
		kernel_initializer="he_normal", use_bias=False)(x)
	
	# multiply the attention weights with the original input
	x = Multiply()([shortcut, x])
	# return the output of the SE block
	return x

# %%
from tensorflow.keras.layers import Layer, InputSpec
class Position_Embedding(Layer):

    def __init__(self, size=None, mode='concat', **kwargs):

        self.size = size

        self.mode = mode

        super(Position_Embedding, self).__init__(**kwargs)

    def get_config(self):
        config = super().get_config()
        config.update({
            "arg1": self.size,
            "arg2": self.mode,
        })
        return config

    def call(self, x):

        if (self.size == None) or (self.mode == 'concat'):
            self.size = int(x.shape[-1])

        position_j = 1. / K.pow(10000., 2 * K.arange(self.size / 2, dtype='float32') / self.size)

        position_j = K.expand_dims(position_j, 0)

        position_i = K.cumsum(K.ones_like(x[:, :, 0]), 1) - 1

        position_i = K.expand_dims(position_i, 2)

        position_ij = K.dot(position_i, position_j)

        position_ij = K.concatenate([K.cos(position_ij), K.sin(position_ij)], 2)

        if self.mode == 'sum':

            return position_ij + x

        elif self.mode == 'concat':

            return K.concatenate([position_ij, x], 2)

    def compute_output_shape(self, input_shape):

        if self.mode == 'sum':

            return input_shape

        elif self.mode == 'concat':

            return (input_shape[0], input_shape[1], input_shape[2] + self.size)


class Self_Attention(Layer):
    def __init__(self, output_dim, **kwargs):
        self.output_dim = output_dim
        super(Self_Attention, self).__init__(**kwargs)
    
    def get_config(self):
        config = super().get_config()
        config.update({
            "arg1": self.output_dim,
        })
        return config

    def build(self, input_shape):
        self.kernel = self.add_weight(name='kernel',
                                      shape=(3, input_shape[2], self.output_dim),
                                      initializer='uniform',
                                      trainable=True)

        super(Self_Attention, self).build(input_shape)

    def call(self, x):
        WQ = K.dot(x, self.kernel[0])
        WK = K.dot(x, self.kernel[1])
        WV = K.dot(x, self.kernel[2])
        QK = K.batch_dot(WQ, K.permute_dimensions(WK, [0, 2, 1]))
        QK = QK / (self.output_dim ** 0.5)
        QK = K.softmax(QK)
        V = K.batch_dot(QK, WV)
        return V

    def compute_output_shape(self, input_shape):
        return (input_shape[0], input_shape[1], self.output_dim)

# %%
self_number = 128
weight_decay=0.0001
def get_combined_model():
    ### Head-1:
    input1 = Input(shape=trainX1[0].shape)

    x = Conv1D(filters=64, kernel_size=5, padding='same', kernel_regularizer=l2(l=0.01))(input1)
    x = BatchNormalization()(x)
    x = Dropout(rate=0.50)(x)
    x = Position_Embedding()(x)
    x = Self_Attention(self_number)(x)

    x = Activation('relu')(x)

    x = Dropout(rate = 0.5)(x)

    #x = Conv1D(filters=32, kernel_size=3, padding='same', activation='relu', kernel_regularizer=l2(l=0.01))(x)
    #x = BatchNormalization()(x)
    #x = Dropout(rate=0.50)(x)

    head1 = Flatten()(x)

    #output = Dense(units=128, activation='relu',)(head1)
    #output = BatchNormalization()(output)
    #output = Dropout(rate=0.5)(output)

    #output = Dense(units=64, activation='relu',)(head1)
    #output = BatchNormalization()(output)
    #output = Dropout(rate=0.5)(output)


    #output = Dense(units=32, activation='relu',)(output)
    #output = BatchNormalization()(output)
    #output = Dropout(rate=0.5)(output)
    
    #output = Dense(units=8, activation='relu',)(output)
    #output = BatchNormalization()(output)
    #output = Dropout(rate=0.25)(output)

    x = Model(inputs=[input1], outputs=[head1])


        ### Head-1:
    input2 = Input(shape=trainX2[0].shape)

    y = Conv1D(filters=64, kernel_size=5, padding='same', kernel_regularizer=l2(l=0.01))(input2)
    y = BatchNormalization()(y)
    y = Dropout(rate=0.5)(y)
    y = Position_Embedding()(y)
    y = Self_Attention(self_number)(y)

    y = Activation('relu')(y)

    y = Dropout(rate = 0.5)(y)

    #y = Conv1D(filters=16, kernel_size=3, padding='same', activation='relu', kernel_regularizer=l2(l=0.01))(y)
    #y = BatchNormalization()(y)
    #y = Dropout(rate=0.50)(y)

    head2 = Flatten()(y)
    #output2 = Dense(units=128, activation='relu',)(head2)
    #output2 = BatchNormalization()(output2)
    #output2 = Dropout(rate=0.5)(output2)

    #output2 = Dense(units=64, activation='relu',)(head2)
    #output2 = BatchNormalization()(output2)
    #output2 = Dropout(rate=0.5)(output2)


    #output2 = Dense(units=32, activation='relu',)(output2)
    #output2 = BatchNormalization()(output2)
    #output2 = Dropout(rate=0.5)(output2)
    
    #output2 = Dense(units=8, activation='relu',)(output2)
    #output2 = BatchNormalization()(output2)
    #output2 = Dropout(rate=0.5)(output2)


    y = Model(inputs=[input2], outputs=[head2])

    combined = concatenate([x.output, y.output])

    z= Dense(units=2048, activation='relu', kernel_regularizer=l2(weight_decay),
              bias_regularizer=l2(weight_decay))(combined)
    #output2 = BatchNormalization()(output2)
    z = Dropout(rate=0.5)(z)

    z= Dense(units=1024, activation='relu',kernel_regularizer=l2(weight_decay),
              bias_regularizer=l2(weight_decay))(combined)
    #output2 = BatchNormalization()(output2)
    z = Dropout(rate=0.5)(z)

    z= Dense(units=512, activation='relu',kernel_regularizer=l2(weight_decay),
              bias_regularizer=l2(weight_decay))(combined)
    #output2 = BatchNormalization()(output2)
    z = Dropout(rate=0.5)(z)

    z= Dense(units=256, activation='relu',kernel_regularizer=l2(weight_decay),
              bias_regularizer=l2(weight_decay))(z)
    #output2 = BatchNormalization()(output2)
    z = Dropout(rate=0.5)(z)

    
    z= Dense(units=128, activation='relu',kernel_regularizer=l2(weight_decay),
              bias_regularizer=l2(weight_decay))(z)
    #output2 = BatchNormalization()(output2)
    z = Dropout(rate=0.5)(z)

    z = Dense(units=64, activation='relu',kernel_regularizer=l2(weight_decay),
              bias_regularizer=l2(weight_decay))(z)
    #output2 = BatchNormalization()(output2)
    z = Dropout(rate=0.5)(z)


    z = Dense(units=32, activation='relu',kernel_regularizer=l2(weight_decay),
              bias_regularizer=l2(weight_decay))(z)
    #output2 = BatchNormalization()(output2)
    z = Dropout(rate=0.5)(z)
    
    z = Dense(units=16, activation='relu',kernel_regularizer=l2(weight_decay),
              bias_regularizer=l2(weight_decay))(z)
    #output2 = BatchNormalization()(output2)
    z = Dropout(rate=0.5)(z)
    #z = Dense(8, activation='relu')(z)
    #z = BatchNormalization()(z)
    #z = Dropout(rate=0.5)(z)
    z = Dense(1, activation='sigmoid')(z)
    
    # our model will accept the inputs of the two branches and
    # then output a single value
    return Model(inputs=[x.input, y.input], outputs=z)

# %%
import tensorflow.keras.backend as K
model = get_combined_model()
model.summary()
plot_model(model, to_file='model-combined.png', show_shapes=True, show_layer_names=False, expand_nested=True)
# Out:
# Model: "model_9"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 21, 20)]     0           []
#
#  input_6 (InputLayer)           [(None, 21, 8)]      0           []
#
#  conv1d_4 (Conv1D)              (None, 21, 64)       6464        ['input_5[0][0]']
#
#  conv1d_5 (Conv1D)              (None, 21, 64)       2624        ['input_6[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 21, 64)      256         ['conv1d_4[0][0]']
#  rmalization)
#
#  batch_normalization_5 (BatchNo  (None, 21, 64)      256         ['conv1d_5[0][0]']
#  rmalization)
#
#  dropout_20 (Dropout)           (None, 21, 64)       0           ['batch_normalization_4[0][0]']
#
#  dropout_22 (Dropout)           (None, 21, 64)       0           ['batch_normalization_5[0][0]']
#
#  position__embedding_4 (Positio  (None, 21, 128)     0           ['dropout_20[0][0]']
#  n_Embedding)
#
#  position__embedding_5 (Positio  (None, 21, 128)     0           ['dropout_22[0][0]']
#  n_Embedding)
#
#  self__attention_4 (Self_Attent  (None, 21, 128)     49152       ['position__embedding_4[0][0]']
#  ion)
#
#  self__attention_5 (Self_Attent  (None, 21, 128)     49152       ['position__embedding_5[0][0]']
#  ion)
#
#  activation_2 (Activation)      (None, 21, 128)      0           ['self__attention_4[0][0]']
#
#  activation_3 (Activation)      (None, 21, 128)      0           ['self__attention_5[0][0]']
#
#  dropout_21 (Dropout)           (None, 21, 128)      0           ['activation_2[0][0]']
#
#  dropout_23 (Dropout)           (None, 21, 128)      0           ['activation_3[0][0]']
#
#  flatten_4 (Flatten)            (None, 2688)         0           ['dropout_21[0][0]']
#
#  flatten_5 (Flatten)            (None, 2688)         0           ['dropout_23[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 5376)         0           ['flatten_4[0][0]',
#                                                                   'flatten_5[0][0]']
#
#  dense_18 (Dense)               (None, 512)          2753024     ['concatenate_2[0][0]']
#
#  dropout_26 (Dropout)           (None, 512)          0           ['dense_18[0][0]']
#
#  dense_19 (Dense)               (None, 256)          131328      ['dropout_26[0][0]']
#
#  dropout_27 (Dropout)           (None, 256)          0           ['dense_19[0][0]']
#
#  dense_20 (Dense)               (None, 128)          32896       ['dropout_27[0][0]']
#
#  dropout_28 (Dropout)           (None, 128)          0           ['dense_20[0][0]']
#
#  dense_21 (Dense)               (None, 64)           8256        ['dropout_28[0][0]']
#
#  dropout_29 (Dropout)           (None, 64)           0           ['dense_21[0][0]']
#
#  dense_22 (Dense)               (None, 32)           2080        ['dropout_29[0][0]']
#
#  dropout_30 (Dropout)           (None, 32)           0           ['dense_22[0][0]']
#
#  dense_23 (Dense)               (None, 16)           528         ['dropout_30[0][0]']
#
#  dropout_31 (Dropout)           (None, 16)           0           ['dense_23[0][0]']
#
#  dense_24 (Dense)               (None, 1)            17          ['dropout_31[0][0]']
#
# ==================================================================================================
# Total params: 3,036,033
# Trainable params: 3,035,777
# Non-trainable params: 256
# __________________________________________________________________________________________________

# %%
# patient early stopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)
# save the best model
mc = ModelCheckpoint('best_model_combined.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)

# %%
# Compile Model:
from tensorflow.keras.optimizers import (RMSprop, Adam, SGD)
model.compile(optimizer=Adam(learning_rate=0.0005), loss='binary_crossentropy',metrics=['accuracy'])

# Run Model:
#history = model.fit(x=trainX1, y= y_train, validation_data=(testX1, y_test), batch_size=16, epochs=100, verbose=1, callbacks=[])
history=model.fit(x=[trainX1, trainX2], y=y_train, validation_data=([valX1, valtX2], y_val), epochs=100, batch_size=32, callbacks=[es,mc], verbose = 1)
# Out:
# Epoch 1/100
# 1550/1552 [============================>.] - ETA: 0s - loss: 0.8357 - accuracy: 0.6249
# Epoch 1: val_accuracy improved from -inf to 0.71317, saving model to best_model_combined.h5
# 1552/1552 [==============================] - 16s 9ms/step - loss: 0.8357 - accuracy: 0.6249 - val_loss: 0.7216 - val_accuracy: 0.7132
# Epoch 2/100
# 1551/1552 [============================>.] - ETA: 0s - loss: 0.6902 - accuracy: 0.7245
# Epoch 2: val_accuracy did not improve from 0.71317
# 1552/1552 [==============================] - 12s 8ms/step - loss: 0.6902 - accuracy: 0.7245 - val_loss: 0.7179 - val_accuracy: 0.6849
# Epoch 3/100
# 1551/1552 [============================>.] - ETA: 0s - loss: 0.6419 - accuracy: 0.7498
# Epoch 3: val_accuracy improved from 0.71317 to 0.72767, saving model to best_model_combined.h5
# 1552/1552 [==============================] - 14s 9ms/step - loss: 0.6418 - accuracy: 0.7498 - val_loss: 0.6831 - val_accuracy: 0.7277
# Epoch 4/100
# 1550/1552 [============================>.] - ETA: 0s - loss: 0.6092 - accuracy: 0.7693
# Epoch 4: val_accuracy improved from 0.72767 to 0.74977, saving model to best_model_combined.h5
# 1552/1552 [==============================] - 13s 8ms/step - loss: 0.6091 - accuracy: 0.7694 - val_loss: 0.6528 - val_accuracy: 0.7498
# Epoch 5/100
# 1547/1552 [============================>.] - ETA: 0s - loss: 0.5917 - accuracy: 0.7851
# Epoch 5: val_accuracy improved from 0.74977 to 0.76209, saving model to best_model_combined.h5
# 1552/1552 [==============================] - 13s 8ms/step - loss: 0.5918 - accuracy: 0.7852 - val_loss: 0.6476 - val_accuracy: 0.7621
# Epoch 6/100
# 1547/1552 [============================>.] - ETA: 0s - loss: 0.5704 - accuracy: 0.7958
# Epoch 6: val_accuracy did not improve from 0.76209
# 1552/1552 [==============================] - 12s 8ms/step - loss: 0.5704 - accuracy: 0.7957 - val_loss: 0.9792 - val_accuracy: 0.6362
# Epoch 7/100
# 1549/1552 [============================>.] - ETA: 0s - loss: 0.5605 - accuracy: 0.8001
# Epoch 7: val_accuracy did not improve from 0.76209
# 1552/1552 [==============================] - 12s 8ms/step - loss: 0.5604 - accuracy: 0.8001 - val_loss: 0.8023 - val_accuracy: 0.7146
# Epoch 8/100
# 1549/1552 [============================>.] - ETA: 0s - loss: 0.5467 - accuracy: 0.8143
# Epoch 8: val_accuracy did not improve from 0.76209
# 1552/1552 [==============================] - 14s 9ms/step - loss: 0.5467 - accuracy: 0.8142 - val_loss: 0.9904 - val_accuracy: 0.6626
# Epoch 9/100
# 1552/1552 [==============================] - ETA: 0s - loss: 0.5407 - accuracy: 0.8202
# Epoch 9: val_accuracy did not improve from 0.76209
# 1552/1552 [==============================] - 13s 9ms/step - loss: 0.5407 - accuracy: 0.8202 - val_loss: 1.4274 - val_accuracy: 0.5816
# Epoch 10/100
# 1550/1552 [============================>.] - ETA: 0s - loss: 0.5355 - accuracy: 0.8210
# Epoch 10: val_accuracy did not improve from 0.76209
# 1552/1552 [==============================] - 12s 8ms/step - loss: 0.5355 - accuracy: 0.8210 - val_loss: 1.8004 - val_accuracy: 0.5541
# Epoch 11/100
# 1552/1552 [==============================] - ETA: 0s - loss: 0.5413 - accuracy: 0.8162
# Epoch 11: val_accuracy did not improve from 0.76209
# 1552/1552 [==============================] - 12s 8ms/step - loss: 0.5413 - accuracy: 0.8162 - val_loss: 2.1777 - val_accuracy: 0.5363
# Epoch 12/100
# 1546/1552 [============================>.] - ETA: 0s - loss: 0.5302 - accuracy: 0.8261
# Epoch 12: val_accuracy did not improve from 0.76209
# 1552/1552 [==============================] - 13s 8ms/step - loss: 0.5302 - accuracy: 0.8260 - val_loss: 1.4290 - val_accuracy: 0.5994
# Epoch 13/100
# 1549/1552 [============================>.] - ETA: 0s - loss: 0.5334 - accuracy: 0.8215
# Epoch 13: val_accuracy did not improve from 0.76209
# 1552/1552 [==============================] - 13s 8ms/step - loss: 0.5332 - accuracy: 0.8215 - val_loss: 1.7503 - val_accuracy: 0.5691
# Epoch 14/100
# 1548/1552 [============================>.] - ETA: 0s - loss: 0.5292 - accuracy: 0.8233
# Epoch 14: val_accuracy did not improve from 0.76209
# 1552/1552 [==============================] - 14s 9ms/step - loss: 0.5292 - accuracy: 0.8233 - val_loss: 2.0625 - val_accuracy: 0.5461
# Epoch 15/100
# 1548/1552 [============================>.] - ETA: 0s - loss: 0.5286 - accuracy: 0.8254
# Epoch 15: val_accuracy did not improve from 0.76209
# 1552/1552 [==============================] - 12s 8ms/step - loss: 0.5287 - accuracy: 0.8252 - val_loss: 1.6987 - val_accuracy: 0.5494
# Epoch 15: early stopping

# %%
from matplotlib import pyplot as plt
#plot training and validation accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
#plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train','validation'], loc='lower left')
plt.savefig('accuracy_curve_combined.png')
plt.show()

# %%
#plot training loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.plot()
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train','validation'], loc='upper right')
plt.savefig('loss_curve_combined.png')
plt.show()

# %%
probabilities = model.predict([testX1,testX2])
predicted_classes = probabilities >= 0.5
predicted_classes = predicted_classes.astype(int)

# %%
res = model.evaluate([testX1,testX2], y_test)
# Out:
# 229/229 [==============================] - 1s 4ms/step - loss: 1.1209 - accuracy: 0.3430

# %%
res
# Out:
# [0.5982548594474792, 0.8894059658050537]

# %%
acc,  sensitivity, specificity, precision, MCC = calculate_performance(len(y_test), predicted_classes, y_test)
print('Result Summary:')
print('------------------------------')
print('accuracy',acc, end =", ")
print('MCC',MCC, end =", ")
print('sensitivity',sensitivity, end =",")
print('precision',precision, end =",")
print('specificity',specificity)
# Out:
# Result Summary:
# ------------------------------
# accuracy 0.34300574869969885, MCC 0.06992976420796893, sensitivity 0.8259803921568627,precision 0.06652191077773391,specificity 0.3144389678167585

# %%
from tensorflow.keras.models import load_model
model = load_model('/content/best_model_combined.h5')
probabilities = model.predict([valX1,valtX2])
predicted_classes = probabilities >= 0.5
predicted_classes = predicted_classes.astype(int)
res = model.evaluate([testX1,testX2], y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-4bb1374b79d8> in <module>()
#       1 from tensorflow.keras.models import load_model
# ----> 2 model = load_model('/content/best_model_combined.h5')
#       3 probabilities = model.predict([valX1,valtX2])
#       4 predicted_classes = probabilities >= 0.5
#       5 predicted_classes = predicted_classes.astype(int)
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py in class_and_config_for_serialized_keras_object(config, module_objects, custom_objects, printable_module_name)
#     561   if cls is None:
#     562     raise ValueError(
# --> 563         f'Unknown {printable_module_name}: {class_name}. Please ensure this '
#     564         'object is passed to the `custom_objects` argument. See '
#     565         'https://www.tensorflow.org/guide/keras/save_and_serialize'
#
# ValueError: Unknown layer: Position_Embedding. Please ensure this object is passed to the `custom_objects` argument. See https://www.tensorflow.org/guide/keras/save_and_serialize#registering_the_custom_object for details.

# %%
acc,  sensitivity, specificity, precision, MCC = calculate_performance(len(y_val), predicted_classes, y_val)
print('Result Summary:')
print('------------------------------')
print('accuracy',acc, end =", ")
print('MCC',MCC, end =", ")
print('sensitivity',sensitivity, end =",")
print('precision',precision, end =",")
print('specificity',specificity)
# Out:
# Result Summary:
# ------------------------------
# accuracy 0.9780757383583982, MCC 0.9569411737911745, sensitivity 0.9989308624376336,precision 0.9596028757274906,specificity 0.9565057132325838

# %%
# Outputs of the 8 layers, which include conv2D and max pooling layers
layer_outputs = model.layers[13]
activation_model = Model(inputs = model.input, outputs = layer_outputs.output)
activations = activation_model.predict([valX1, valtX2])

# %%
activations[0].shape
# Out:
# (2688,)

# %%
from sklearn.manifold import TSNE
import pandas as pd
import seaborn as sns
 
# We want to get TSNE embedding with 2 dimensions
n_components = 2
tsne = TSNE(n_components)
tsne_result = tsne.fit_transform(activations)
tsne_result.shape
# (1000, 2)
# Two dimensions for each of our images
 
# Plot the result of our TSNE with the label color coded
# A lot of the stuff here is about making the plot look pretty and not TSNE
tsne_result_df = pd.DataFrame({'tsne_1': tsne_result[:,0], 'tsne_2': tsne_result[:,1], 'label': y_val})
fig, ax = plt.subplots(1)
sns.scatterplot(x='tsne_1', y='tsne_2', hue='label', data=tsne_result_df, ax=ax,s=120)
lim = (tsne_result.min()-5, tsne_result.max()+5)
ax.set_xlim(lim)
ax.set_ylim(lim)
ax.set_aspect('equal')
ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.0)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
